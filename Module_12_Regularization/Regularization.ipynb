# %% [markdown]
# <a href="https://colab.research.google.com/github/MySureStart/mit_futuremakers_summer_2023-ezou6/blob/main/Module_12_Regularization/Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image_2021-10-30_133041.png](data:image/png;base64,...)

# %% [markdown]
# #Objective
# * To acquaint you with the problem of overfit models and to mitigate it with regularization

# %%
# Basic packages
import pandas as pd
import numpy as np
import re
import collections
import matplotlib.pyplot as plt
from pathlib import Path

# Packages for data preparation
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from keras.preprocessing.text import Tokenizer
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelEncoder

import nltk
nltk.download('stopwords')

# Packages for modeling
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import regularizers

NB_WORDS = 10000  # Parameter indicating the number of words we'll put in the dictionary
NB_START_EPOCHS = 20  # Number of epochs we usually start to train with
BATCH_SIZE = 512  # Size of the batches used in the mini-batch gradient descent
MAX_LEN = 20  # Maximum number of words in a sequence

root = Path('../content/')
input_path = root / 'input/'
ouput_path = root / 'output/'
source_path = root / 'source/'

def deep_model(model, X_train, y_train, X_valid, y_valid):
    model.compile(optimizer='rmsprop'
                  , loss='categorical_crossentropy'
                  , metrics=['accuracy'])

    history = model.fit(X_train
                       , y_train
                       , epochs=NB_START_EPOCHS
                       , batch_size=BATCH_SIZE
                       , validation_data=(X_valid, y_valid)
                       , verbose=1)
    return history

def eval_metric(model, history, metric_name):
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]

    e = range(1, NB_START_EPOCHS + 1)

    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    plt.show()

def remove_stopwords(input_text):
    stopwords_list = stopwords.words('english')
    # Some words which might indicate a certain sentiment are kept via a whitelist
    whitelist = ["n't", "not", "no"]
    words = input_text.split()
    clean_words = [word for word in words if (word not in stopwords_list or word in whitelist) and len(word) > 1]
    return " ".join(clean_words)

def remove_mentions(input_text):
    return re.sub(r'@\w+', '', input_text)

def test_model(model, X_train, y_train, X_test, y_test, epoch_stop):
    model.fit(X_train
              , y_train
              , epochs=epoch_stop
              , batch_size=BATCH_SIZE
              , verbose=1)
    results = model.evaluate(X_test, y_test)
    print()
    print('Test accuracy: {0:.2f}%'.format(results[1]*100))
    return results

def compare_models_by_metric(model_1, model_2, model_hist_1, model_hist_2, metric):
    metric_model_1 = model_hist_1.history[metric]
    metric_model_2 = model_hist_2.history[metric]

    e = range(1, NB_START_EPOCHS + 1)

    metrics_dict = {
        'acc' : 'Training Accuracy',
        'loss' : 'Training Loss',
        'val_acc' : 'Validation accuracy',
        'val_loss' : 'Validation loss'
    }

    metric_label = metrics_dict[metric]

    plt.plot(e, metric_model_1, 'bo', label=model_1.name)
    plt.plot(e, metric_model_2, 'b', label=model_2.name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_label)
    plt.title('Comparing ' + metric_label + ' between models')
    plt.legend()
    plt.show()

def optimal_epoch(model_hist):
    min_epoch = np.argmin(model_hist.history['val_loss']) + 1
    print("Minimum validation loss reached in epoch {}".format(min_epoch))
    return min_epoch

! gdown --id 1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
! mkdir input/
! mv Tweets.csv input/

df = pd.read_csv(input_path / 'Tweets.csv')
df = df.reindex(np.random.permutation(df.index))
df = df[['text', 'airline_sentiment']]
df.text = df.text.apply(remove_stopwords).apply(remove_mentions)

X_train, X_test, y_train, y_test = train_test_split(df.text, df.airline_sentiment, test_size=0.1, random_state=37)

tk = Tokenizer(num_words=NB_WORDS,
               filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~\t\n',
               lower=True,
               char_level=False,
               split=' ')
tk.fit_on_texts(X_train)

X_train_oh = tk.texts_to_matrix(X_train, mode='binary')
X_test_oh = tk.texts_to_matrix(X_test, mode='binary')

le = LabelEncoder()
y_train_le = le.fit_transform(y_train)
y_test_le = le.transform(y_test)
y_train_oh = to_categorical(y_train_le)
y_test_oh = to_categorical(y_test_le)

X_train_rest, X_valid, y_train_rest, y_valid = train_test_split(X_train_oh, y_train_oh, test_size=0.1, random_state=37)

base_model = models.Sequential()
base_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
base_model.add(layers.Dense(64, activation='relu'))
base_model.add(layers.Dense(3, activation='softmax'))
base_history = deep_model(base_model, X_train_rest, y_train_rest, X_valid, y_valid)
base_min = optimal_epoch(base_history)

reduced_model = models.Sequential()
reduced_model.add(layers.Dense(16, activation='relu', input_shape=(NB_WORDS,)))
reduced_model.add(layers.Dense(3, activation='softmax'))
reduced_history = deep_model(reduced_model, X_train_rest, y_train_rest, X_valid, y_valid)
reduced_min = optimal_epoch(reduced_history)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
# To: /content/Tweets.csv
# 100% 3.42M/3.42M [00:00<00:00, 197MB/s]
# Epoch 1/20
# 24/24 [==============================] - 6s 29ms/step - loss: 0.8770 - accuracy: 0.6192 - val_loss: 0.7578 - val_accuracy: 0.6366
# Epoch 2/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.6536 - accuracy: 0.7136 - val_loss: 0.6354 - val_accuracy: 0.7564
# Epoch 3/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.5146 - accuracy: 0.8210 - val_loss: 0.5799 - val_accuracy: 0.7678
# Epoch 4/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.4132 - accuracy: 0.8567 - val_loss: 0.5745 - val_accuracy: 0.7754
# Epoch 5/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.3457 - accuracy: 0.8810 - val_loss: 0.5578 - val_accuracy: 0.7906
# Epoch 6/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2947 - accuracy: 0.8990 - val_loss: 0.5679 - val_accuracy: 0.7929
# Epoch 7/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2523 - accuracy: 0.9127 - val_loss: 0.6070 - val_accuracy: 0.7830
# Epoch 8/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2158 - accuracy: 0.9292 - val_loss: 0.6241 - val_accuracy: 0.7785
# Epoch 9/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1867 - accuracy: 0.9386 - val_loss: 0.6943 - val_accuracy: 0.7792
# Epoch 10/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1615 - accuracy: 0.9486 - val_loss: 0.6795 - val_accuracy: 0.7807
# Epoch 11/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1414 - accuracy: 0.9551 - val_loss: 0.7207 - val_accuracy: 0.7800
# Epoch 12/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1217 - accuracy: 0.9628 - val_loss: 0.7510 - val_accuracy: 0.7754
# Epoch 13/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1063 - accuracy: 0.9673 - val_loss: 0.8135 - val_accuracy: 0.7747
# Epoch 14/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0921 - accuracy: 0.9719 - val_loss: 0.8908 - val_accuracy: 0.7830
# Epoch 15/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0813 - accuracy: 0.9756 - val_loss: 0.9334 - val_accuracy: 0.7709
# Epoch 16/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0714 - accuracy: 0.9786 - val_loss: 1.0232 - val_accuracy: 0.7785
# Epoch 17/20
# 24/24 [==============================] - 0s 21ms/step - loss: 0.0636 - accuracy: 0.9818 - val_loss: 1.0001 - val_accuracy: 0.7716
# Epoch 18/20
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0568 - accuracy: 0.9830 - val_loss: 1.0330 - val_accuracy: 0.7656
# Epoch 19/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.0517 - accuracy: 0.9853 - val_loss: 1.1189 - val_accuracy: 0.7754
# Epoch 20/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0470 - accuracy: 0.9868 - val_loss: 1.1479 - val_accuracy: 0.7747
# Minimum validation loss reached in epoch 5
# Epoch 1/20
# 24/24 [==============================] - 1s 25ms/step - loss: 0.9655 - accuracy: 0.6219 - val_loss: 0.8711 - val_accuracy: 0.6366
# Epoch 2/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.8064 - accuracy: 0.6520 - val_loss: 0.7767 - val_accuracy: 0.6578
# Epoch 3/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.7170 - accuracy: 0.6878 - val_loss: 0.7205 - val_accuracy: 0.6889
# Epoch 4/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.6532 - accuracy: 0.7246 - val_loss: 0.6802 - val_accuracy: 0.7238
# Epoch 5/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.6011 - accuracy: 0.7630 - val_loss: 0.6491 - val_accuracy: 0.7436
# Epoch 6/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.5576 - accuracy: 0.7956 - val_loss: 0.6216 - val_accuracy: 0.7557
# Epoch 7/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.5197 - accuracy: 0.8219 - val_loss: 0.6003 - val_accuracy: 0.7610
# Epoch 8/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.4871 - accuracy: 0.8388 - val_loss: 0.5822 - val_accuracy: 0.7739
# Epoch 9/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.4578 - accuracy: 0.8506 - val_loss: 0.5693 - val_accuracy: 0.7777
# Epoch 10/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.4323 - accuracy: 0.8592 - val_loss: 0.5586 - val_accuracy: 0.7777
# Epoch 11/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.4100 - accuracy: 0.8657 - val_loss: 0.5529 - val_accuracy: 0.7815
# Epoch 12/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.3903 - accuracy: 0.8711 - val_loss: 0.5471 - val_accuracy: 0.7830
# Epoch 13/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.3720 - accuracy: 0.8749 - val_loss: 0.5397 - val_accuracy: 0.7876
# Epoch 14/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3559 - accuracy: 0.8822 - val_loss: 0.5393 - val_accuracy: 0.7898
# Epoch 15/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3413 - accuracy: 0.8851 - val_loss: 0.5399 - val_accuracy: 0.7921
# Epoch 16/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.3281 - accuracy: 0.8921 - val_loss: 0.5362 - val_accuracy: 0.7906
# Epoch 17/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3159 - accuracy: 0.8965 - val_loss: 0.5359 - val_accuracy: 0.7929
# Epoch 18/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.3041 - accuracy: 0.9000 - val_loss: 0.5374 - val_accuracy: 0.7944
# Epoch 19/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2934 - accuracy: 0.9039 - val_loss: 0.5407 - val_accuracy: 0.7936
# Epoch 20/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2830 - accuracy: 0.9066 - val_loss: 0.5461 - val_accuracy: 0.7929
# Minimum validation loss reached in epoch 17

# %% [markdown]
# # Applying regularization
#
# You may be familiar with Occam's Razor principle: given two explanations for something, the explanation most likely to be correct is the "simplest" one, the one that makes the least amount of assumptions. This also applies to the models learned by neural networks: given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.
#
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether, as we saw in the section above). Thus a common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular". This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# L1 regularization, where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# L2 regularization, where the cost added is proportional to the square of the value of the weights coefficients (i.e. to what is called the squared "L2 norm" of the weights). L2 regularization is also called weight decay in the context of neural networks. Don't let the different name confuse you: weight decay is mathematically the exact same as L2 regularization.
#
# L1 regularization pushes weights towards exactly zero encouraging a sparse model. L2 regularization will penalize the weights parameters without making them sparse since the penalty goes to zero for small weights-one reason why L2 is more common.
#
# In `tf.keras`, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. Let's add L2 weight regularization now.

# %%
reg_model = models.Sequential()
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu', input_shape=(NB_WORDS,)))
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu'))
reg_model.add(layers.Dense(3, activation='softmax'))
reg_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 64)                640064
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
reg_history = deep_model(reg_model, X_train_rest, y_train_rest, X_valid, y_valid)
reg_min = optimal_epoch(reg_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 2s 28ms/step - loss: 1.0752 - accuracy: 0.6075 - val_loss: 0.9324 - val_accuracy: 0.6320
# Epoch 2/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.8201 - accuracy: 0.7102 - val_loss: 0.7840 - val_accuracy: 0.7405
# Epoch 3/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.6643 - accuracy: 0.8085 - val_loss: 0.7070 - val_accuracy: 0.7610
# Epoch 4/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.5636 - accuracy: 0.8458 - val_loss: 0.6612 - val_accuracy: 0.7853
# Epoch 5/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.4980 - accuracy: 0.8678 - val_loss: 0.6528 - val_accuracy: 0.7906
# Epoch 6/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.4512 - accuracy: 0.8851 - val_loss: 0.6671 - val_accuracy: 0.7868
# Epoch 7/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.4143 - accuracy: 0.8961 - val_loss: 0.6679 - val_accuracy: 0.7906
# Epoch 8/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.3837 - accuracy: 0.9068 - val_loss: 0.7025 - val_accuracy: 0.7830
# Epoch 9/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.3595 - accuracy: 0.9153 - val_loss: 0.7177 - val_accuracy: 0.7845
# Epoch 10/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.3389 - accuracy: 0.9261 - val_loss: 0.7240 - val_accuracy: 0.7868
# Epoch 11/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3200 - accuracy: 0.9342 - val_loss: 0.7292 - val_accuracy: 0.7785
# Epoch 12/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3050 - accuracy: 0.9405 - val_loss: 0.7258 - val_accuracy: 0.7876
# Epoch 13/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2901 - accuracy: 0.9447 - val_loss: 0.7422 - val_accuracy: 0.7731
# Epoch 14/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2784 - accuracy: 0.9494 - val_loss: 0.7551 - val_accuracy: 0.7724
# Epoch 15/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2675 - accuracy: 0.9529 - val_loss: 0.7736 - val_accuracy: 0.7739
# Epoch 16/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.2560 - accuracy: 0.9576 - val_loss: 0.7831 - val_accuracy: 0.7693
# Epoch 17/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2473 - accuracy: 0.9599 - val_loss: 0.7947 - val_accuracy: 0.7678
# Epoch 18/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2392 - accuracy: 0.9653 - val_loss: 0.8108 - val_accuracy: 0.7693
# Epoch 19/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2325 - accuracy: 0.9646 - val_loss: 0.8099 - val_accuracy: 0.7709
# Epoch 20/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.2235 - accuracy: 0.9688 - val_loss: 0.8721 - val_accuracy: 0.7716
# Minimum validation loss reached in epoch 5

# %% [markdown]
# For the regularized model we notice that it starts overfitting in the same epoch as the baseline model. However, the loss increases much slower afterwards.

# %%
eval_metric(reg_model, reg_history, 'loss')

# %%
compare_models_by_metric(base_model, reg_model, base_history, reg_history, 'val_loss')

# %% [markdown]
# ## Question 1
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 1

# %%
#L1 regularization

weights = [-5, 4, -3, 2, 1]

def l1_norm(weights, lamb):
  reg = []
  for weight in weights:
    weight = abs(weight) * lamb
    reg.append(weight)
  return reg

print(l1_norm(weights, .001))
# Out:
# [0.005, 0.004, 0.003, 0.002, 0.001]

# %% [markdown]
# ## Question 2
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||_2^2$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 2

# %%
#L2 regularization

weights = [-5, 4, -3, 2, 1]

def l2_norm(weights, lamb):
  reg = []
  for weight in weights:
    weight = (weight)**2 * lamb
    reg.append(weight)
  return reg

print(l2_norm(weights, .001))
# Out:
# [0.025, 0.016, 0.009000000000000001, 0.004, 0.001]

# %% [markdown]
# ## Adding dropout layers
# Add dropout
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks, developed by Hinton and his students at the University of Toronto.
#
# The intuitive explanation for dropout is that because individual nodes in the network cannot rely on the output of the others, each node must output features that are useful on their own.
#
# Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training. Let's say a given layer would normally have returned a vector [0.2, 0.5, 1.3, 0.8, 1.1] for a given input sample during training; after applying dropout, this vector will have a few zero entries distributed at random, e.g. [0, 0.5, 1.3, 0, 1.1].
#
# The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.
#
# In `tf.keras` you can introduce dropout in a network via the Dropout layer, which gets applied to the output of layer right before.
#
# Let's add two Dropout layers in our network to see how well they do at reducing overfitting:

# %%
drop_model = models.Sequential()
drop_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(64, activation='relu'))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(3, activation='softmax'))
drop_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 64)                640064
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_9 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
drop_history = deep_model(drop_model, X_train_rest, y_train_rest, X_valid, y_valid)
drop_min = optimal_epoch(drop_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 2s 26ms/step - loss: 0.8719 - accuracy: 0.6175 - val_loss: 0.7652 - val_accuracy: 0.6199
# Epoch 2/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.7113 - accuracy: 0.6558 - val_loss: 0.6849 - val_accuracy: 0.7049
# Epoch 3/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.6217 - accuracy: 0.7515 - val_loss: 0.6226 - val_accuracy: 0.7549
# Epoch 4/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.5413 - accuracy: 0.8015 - val_loss: 0.5826 - val_accuracy: 0.7716
# Epoch 5/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.4815 - accuracy: 0.8287 - val_loss: 0.5594 - val_accuracy: 0.7792
# Epoch 6/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.4322 - accuracy: 0.8474 - val_loss: 0.5687 - val_accuracy: 0.7785
# Epoch 7/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.3873 - accuracy: 0.8657 - val_loss: 0.5675 - val_accuracy: 0.7883
# Epoch 8/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.3524 - accuracy: 0.8771 - val_loss: 0.5852 - val_accuracy: 0.7868
# Epoch 9/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.3251 - accuracy: 0.8870 - val_loss: 0.5938 - val_accuracy: 0.7838
# Epoch 10/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2995 - accuracy: 0.8942 - val_loss: 0.5862 - val_accuracy: 0.7891
# Epoch 11/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.2740 - accuracy: 0.9066 - val_loss: 0.6181 - val_accuracy: 0.7891
# Epoch 12/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2569 - accuracy: 0.9098 - val_loss: 0.6345 - val_accuracy: 0.7876
# Epoch 13/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2348 - accuracy: 0.9197 - val_loss: 0.6450 - val_accuracy: 0.7906
# Epoch 14/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2191 - accuracy: 0.9260 - val_loss: 0.6774 - val_accuracy: 0.7876
# Epoch 15/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2035 - accuracy: 0.9336 - val_loss: 0.6752 - val_accuracy: 0.7868
# Epoch 16/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1880 - accuracy: 0.9365 - val_loss: 0.7013 - val_accuracy: 0.7860
# Epoch 17/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1778 - accuracy: 0.9411 - val_loss: 0.7412 - val_accuracy: 0.7845
# Epoch 18/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1600 - accuracy: 0.9472 - val_loss: 0.7402 - val_accuracy: 0.7860
# Epoch 19/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1500 - accuracy: 0.9518 - val_loss: 0.7719 - val_accuracy: 0.7785
# Epoch 20/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.1441 - accuracy: 0.9525 - val_loss: 0.7782 - val_accuracy: 0.7754
# Minimum validation loss reached in epoch 5

# %%
eval_metric(drop_model, drop_history, 'loss')

# %% [markdown]
# The model with dropout layers starts overfitting later than the baseline model. The loss also increases slower than the baseline model.

# %%
compare_models_by_metric(base_model, drop_model, base_history, drop_history, 'val_loss')

# %%
compare_models_by_metric(reg_model, drop_model, reg_history, drop_history, 'val_loss')

# %% [markdown]
# The model with the Dropout layers starts overfitting later. Compared to the baseline model the loss also remains much lower.

# %% [markdown]
# ## Combined L2 + dropout

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu', input_shape=(NB_WORDS,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(3, activation = 'softmax')
])

# %%
combined_history = deep_model(combined_model, X_train_rest, y_train_rest, X_valid, y_valid)
combined_min = optimal_epoch(combined_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 2s 33ms/step - loss: 1.0531 - accuracy: 0.6203 - val_loss: 0.9608 - val_accuracy: 0.6730
# Epoch 2/20
# 24/24 [==============================] - 1s 24ms/step - loss: 0.8799 - accuracy: 0.7158 - val_loss: 0.8953 - val_accuracy: 0.7155
# Epoch 3/20
# 24/24 [==============================] - 1s 25ms/step - loss: 0.7644 - accuracy: 0.7813 - val_loss: 0.9880 - val_accuracy: 0.7451
# Epoch 4/20
# 24/24 [==============================] - 1s 24ms/step - loss: 0.6518 - accuracy: 0.8393 - val_loss: 0.9263 - val_accuracy: 0.7693
# Epoch 5/20
# 24/24 [==============================] - 1s 27ms/step - loss: 0.5291 - accuracy: 0.8948 - val_loss: 0.9016 - val_accuracy: 0.7587
# Epoch 6/20
# 24/24 [==============================] - 1s 22ms/step - loss: 0.4542 - accuracy: 0.9217 - val_loss: 0.9489 - val_accuracy: 0.7777
# Epoch 7/20
# 24/24 [==============================] - 0s 21ms/step - loss: 0.3857 - accuracy: 0.9424 - val_loss: 1.1956 - val_accuracy: 0.7731
# Epoch 8/20
# 24/24 [==============================] - 1s 22ms/step - loss: 0.3394 - accuracy: 0.9604 - val_loss: 1.3772 - val_accuracy: 0.7724
# Epoch 9/20
# 24/24 [==============================] - 1s 21ms/step - loss: 0.3072 - accuracy: 0.9701 - val_loss: 1.1978 - val_accuracy: 0.7618
# Epoch 10/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.2776 - accuracy: 0.9795 - val_loss: 1.3007 - val_accuracy: 0.7815
# Epoch 11/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.2668 - accuracy: 0.9810 - val_loss: 1.3207 - val_accuracy: 0.7853
# Epoch 12/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.2496 - accuracy: 0.9856 - val_loss: 1.4746 - val_accuracy: 0.7785
# Epoch 13/20
# 24/24 [==============================] - 0s 21ms/step - loss: 0.2435 - accuracy: 0.9844 - val_loss: 1.5184 - val_accuracy: 0.7762
# Epoch 14/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.2299 - accuracy: 0.9884 - val_loss: 1.4034 - val_accuracy: 0.7815
# Epoch 15/20
# 24/24 [==============================] - 0s 19ms/step - loss: 0.2261 - accuracy: 0.9891 - val_loss: 1.4960 - val_accuracy: 0.7762
# Epoch 16/20
# 24/24 [==============================] - 0s 19ms/step - loss: 0.2196 - accuracy: 0.9895 - val_loss: 1.4947 - val_accuracy: 0.7769
# Epoch 17/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.2109 - accuracy: 0.9912 - val_loss: 1.4411 - val_accuracy: 0.7785
# Epoch 18/20
# 24/24 [==============================] - 0s 19ms/step - loss: 0.2079 - accuracy: 0.9905 - val_loss: 1.6539 - val_accuracy: 0.7724
# Epoch 19/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.1992 - accuracy: 0.9920 - val_loss: 1.4397 - val_accuracy: 0.7709
# Epoch 20/20
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1900 - accuracy: 0.9925 - val_loss: 1.4974 - val_accuracy: 0.7777
# Minimum validation loss reached in epoch 2

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(256, kernel_regularizer=regularizers.l2(0.001),
                 activation='relu', input_shape=(NB_WORDS,)),
    layers.Dropout(0.3),
    layers.Dense(400, kernel_regularizer=regularizers.l2(0.001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(256, kernel_regularizer=regularizers.l2(0.001),
                 activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(3, activation = 'softmax')
])

combined_history = deep_model(combined_model, X_train_rest, y_train_rest, X_valid, y_valid)
combined_min = optimal_epoch(combined_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 2s 29ms/step - loss: 1.8225 - accuracy: 0.6100 - val_loss: 1.5750 - val_accuracy: 0.6646
# Epoch 2/20
# 24/24 [==============================] - 0s 17ms/step - loss: 1.3878 - accuracy: 0.7489 - val_loss: 1.3131 - val_accuracy: 0.7375
# Epoch 3/20
# 24/24 [==============================] - 0s 18ms/step - loss: 1.0888 - accuracy: 0.8273 - val_loss: 1.1145 - val_accuracy: 0.7822
# Epoch 4/20
# 24/24 [==============================] - 0s 19ms/step - loss: 0.8797 - accuracy: 0.8657 - val_loss: 1.0477 - val_accuracy: 0.7830
# Epoch 5/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.7156 - accuracy: 0.8982 - val_loss: 1.0134 - val_accuracy: 0.7762
# Epoch 6/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.5899 - accuracy: 0.9231 - val_loss: 0.9717 - val_accuracy: 0.7838
# Epoch 7/20
# 24/24 [==============================] - 0s 19ms/step - loss: 0.4927 - accuracy: 0.9389 - val_loss: 0.9418 - val_accuracy: 0.7807
# Epoch 8/20
# 24/24 [==============================] - 0s 19ms/step - loss: 0.4116 - accuracy: 0.9545 - val_loss: 0.9425 - val_accuracy: 0.7792
# Epoch 9/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.3551 - accuracy: 0.9632 - val_loss: 0.9951 - val_accuracy: 0.7686
# Epoch 10/20
# 24/24 [==============================] - 1s 22ms/step - loss: 0.3178 - accuracy: 0.9677 - val_loss: 0.9393 - val_accuracy: 0.7747
# Epoch 11/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.2684 - accuracy: 0.9790 - val_loss: 0.9306 - val_accuracy: 0.7792
# Epoch 12/20
# 24/24 [==============================] - 1s 21ms/step - loss: 0.2527 - accuracy: 0.9762 - val_loss: 0.9452 - val_accuracy: 0.7868
# Epoch 13/20
# 24/24 [==============================] - 1s 22ms/step - loss: 0.2340 - accuracy: 0.9787 - val_loss: 0.9487 - val_accuracy: 0.7769
# Epoch 14/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.2219 - accuracy: 0.9777 - val_loss: 0.9192 - val_accuracy: 0.7830
# Epoch 15/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1952 - accuracy: 0.9860 - val_loss: 0.9006 - val_accuracy: 0.7709
# Epoch 16/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.2006 - accuracy: 0.9783 - val_loss: 0.8912 - val_accuracy: 0.7747
# Epoch 17/20
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1755 - accuracy: 0.9861 - val_loss: 0.9093 - val_accuracy: 0.7830
# Epoch 18/20
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1728 - accuracy: 0.9844 - val_loss: 0.9012 - val_accuracy: 0.7747
# Epoch 19/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1680 - accuracy: 0.9852 - val_loss: 0.9674 - val_accuracy: 0.7709
# Epoch 20/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.1580 - accuracy: 0.9870 - val_loss: 0.9212 - val_accuracy: 0.7693
# Minimum validation loss reached in epoch 16

# %%
eval_metric(combined_model, combined_history, 'loss')

# %%
compare_models_by_metric(base_model, combined_model, base_history, combined_history, 'val_loss')

# %% [markdown]
# ## Question 3
#
# When does it make sense to add both L2 regularization and Dropout?
#
# And what did doing so achieve in this case?

# %% [markdown]
# ### Answer 3
#
# When the model is very prone to overfitting that it requires penalty terms on large loss values and sparsity of layers. However, in this instance, the combined model actually increased val loss as compared to the original model and reached maximum val accuracy at a lower epoch.

# %% [markdown]
# #Training on the full train data and evaluation on test data
# At first sight the reduced model seems to be the best model for generalization. But let's check that on the test set.

# %%
base_results = test_model(base_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, base_min) #number of epochs we stopped at
#to reach min val loss
# Out:
# Epoch 1/5
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1505 - accuracy: 0.9655
# Epoch 2/5
# 26/26 [==============================] - 0s 14ms/step - loss: 0.1035 - accuracy: 0.9731
# Epoch 3/5
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0821 - accuracy: 0.9781
# Epoch 4/5
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0672 - accuracy: 0.9810
# Epoch 5/5
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0567 - accuracy: 0.9846
# 46/46 [==============================] - 0s 3ms/step - loss: 0.9274 - accuracy: 0.7971
#
# Test accuracy: 79.71%

# %%
reduced_results = test_model(reduced_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reduced_min)
# Out:
# Epoch 1/17
# 26/26 [==============================] - 0s 13ms/step - loss: 0.3006 - accuracy: 0.8990
# Epoch 2/17
# 26/26 [==============================] - 0s 13ms/step - loss: 0.2896 - accuracy: 0.9016
# Epoch 3/17
# 26/26 [==============================] - 0s 13ms/step - loss: 0.2794 - accuracy: 0.9065
# Epoch 4/17
# 26/26 [==============================] - 0s 13ms/step - loss: 0.2700 - accuracy: 0.9103
# Epoch 5/17
# 26/26 [==============================] - 0s 13ms/step - loss: 0.2609 - accuracy: 0.9129
# Epoch 6/17
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2526 - accuracy: 0.9166
# Epoch 7/17
# 26/26 [==============================] - 0s 13ms/step - loss: 0.2446 - accuracy: 0.9194
# Epoch 8/17
# 26/26 [==============================] - 0s 13ms/step - loss: 0.2367 - accuracy: 0.9220
# Epoch 9/17
# 26/26 [==============================] - 0s 13ms/step - loss: 0.2293 - accuracy: 0.9250
# Epoch 10/17
# 26/26 [==============================] - 0s 13ms/step - loss: 0.2224 - accuracy: 0.9271
# Epoch 11/17
# 26/26 [==============================] - 0s 13ms/step - loss: 0.2158 - accuracy: 0.9299
# Epoch 12/17
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2095 - accuracy: 0.9311
# Epoch 13/17
# 26/26 [==============================] - 0s 13ms/step - loss: 0.2036 - accuracy: 0.9342
# Epoch 14/17
# 26/26 [==============================] - 0s 13ms/step - loss: 0.1979 - accuracy: 0.9369
# Epoch 15/17
# 26/26 [==============================] - 0s 13ms/step - loss: 0.1923 - accuracy: 0.9388
# Epoch 16/17
# 26/26 [==============================] - 0s 13ms/step - loss: 0.1869 - accuracy: 0.9420
# Epoch 17/17
# 26/26 [==============================] - 0s 12ms/step - loss: 0.1819 - accuracy: 0.9438
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5548 - accuracy: 0.8074
#
# Test accuracy: 80.74%

# %%
reg_results = test_model(reg_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reg_min)
# Out:
# Epoch 1/5
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2828 - accuracy: 0.9494
# Epoch 2/5
# 26/26 [==============================] - 0s 15ms/step - loss: 0.2529 - accuracy: 0.9583
# Epoch 3/5
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2367 - accuracy: 0.9634
# Epoch 4/5
# 26/26 [==============================] - 0s 13ms/step - loss: 0.2264 - accuracy: 0.9671
# Epoch 5/5
# 26/26 [==============================] - 0s 13ms/step - loss: 0.2189 - accuracy: 0.9686
# 46/46 [==============================] - 0s 3ms/step - loss: 0.7514 - accuracy: 0.7923
#
# Test accuracy: 79.23%

# %%
drop_results = test_model(drop_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, drop_min)
# Out:
# Epoch 1/5
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2062 - accuracy: 0.9391
# Epoch 2/5
# 26/26 [==============================] - 0s 14ms/step - loss: 0.1828 - accuracy: 0.9433
# Epoch 3/5
# 26/26 [==============================] - 0s 13ms/step - loss: 0.1652 - accuracy: 0.9476
# Epoch 4/5
# 26/26 [==============================] - 0s 13ms/step - loss: 0.1518 - accuracy: 0.9529
# Epoch 5/5
# 26/26 [==============================] - 0s 13ms/step - loss: 0.1435 - accuracy: 0.9549
# 46/46 [==============================] - 0s 3ms/step - loss: 0.7300 - accuracy: 0.8033
#
# Test accuracy: 80.33%

# %% [markdown]
# # Handling Underfitting
# * In a general situation, the best strategy is to increase the model complexity by either increasing the number of parameters of your deep learning model or the order of your model. Underfitting is due to the model being simpler than needed. It fails to capture the patterns in the data. Increasing the model complexity will lead to improvement in training performance. If we use a large enough model it can even achieve a training error of zero i.e. the model will memorize the data and suffer from over-fitting. The goal is to hit the optimal sweet spot.
# * Try to train the model for more epochs. Ensure that the loss is decreasing gradually over the course of the training. Otherwise, it is highly likely that there is some kind of bug or problem in the training code/logic itself.
# * If you aren’t shuffling the data after every epoch, it can harm the model performance. Ensuring that you are shuffling the data is a good check to perform at this point.

# %% [markdown]
# #Conclusion
# To recap: here are the most common ways to prevent overfitting in neural networks:
#
# * Get more training data.
# * Reduce the capacity of the network.
# * Add weight regularization.
# * Add dropout.
#
# Two important approaches not covered in this guide are:
#
# * data-augmentation
# * batch normalization
#
# Remember that each method can help on its own, but often combining them can be even more effective.
#
# here are the ways to prevent underfitting
#
# * Get more training data.
# * Increase the size or number of parameters in the model.
# * Increase the complexity of the model.
# * Increasing the training time, until cost function is minimised.

# %% [markdown]
# # Bonus content - Visualizing L2 regularization

# %%
import numpy as np
#%matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.core.debugger import set_trace
import warnings
warnings.filterwarnings('ignore')
import itertools

# %%
def plot_contour(f, x1bound, x2bound, resolution, ax):
    x1range = np.linspace(x1bound[0], x1bound[1], resolution)
    x2range = np.linspace(x2bound[0], x2bound[1], resolution)
    xg, yg = np.meshgrid(x1range, x2range)
    zg = np.zeros_like(xg)
    for i,j in itertools.product(range(resolution), range(resolution)):
        zg[i,j] = f([xg[i,j], yg[i,j]])
    ax.contour(xg, yg, zg, 100)
    return ax

# %% [markdown]
# Let's create a toy data:

# %%
N = 20
x = np.random.rand(N) * 10
y = -4*x + 10 + 2*np.random.randn(N)

# %% [markdown]
# visualize the regularized **cost function**

# %%
cost = lambda w: .5*np.mean((w[0] + w[1]*x - y)**2)
l2_penalty = lambda w: np.dot(w,w)/2
cost_plus_l2 = lambda w: cost(w) + 5*l2_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l2_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L2 reg. $||w||_2^2$')
plot_contour(cost_plus_l2, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L2 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus Question 1
#
# Plot the same for L1 regularization

# %% [markdown]
# ### Answer

# %%
cost = lambda w: .5*np.mean((w[0] + w[1]*x - y)**2)
l1_penalty = lambda w: np.sum(np.abs(w))
cost_plus_l1 = lambda w: cost(w) + 5*l2_penalty(w)

# cost = lambda w: .5*np.mean((w[0] + w[1]*x - y)**2)
# l2_penalty = lambda w: np.dot(w,w)/2
# cost_plus_l2 = lambda w: cost(w) + 5*l2_penalty(w)


fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l1_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L1 reg. $||w||_2^2$')
plot_contour(cost_plus_l1, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L1 reg. cost $J(w) + 5 |w|')
plt.show()

# %% [markdown]
# ## Bonus Question 2
# After looking at the visualization to what the L1 and L2 normalizations, how do they help while training?
#
# L1 and L2 seem to center the cost function and present a more clear convergence point. L1 introduces sparsity and sets some weights to 0 if they do not contribute enough to the general relationship, which occurs when the cost function meets the corner points of the l2 function, which appears as a diamond.

# %% [markdown]
# # Upload this Colab Notebook to your Github repository. Also add your *reflections* on today's learning in README.md
